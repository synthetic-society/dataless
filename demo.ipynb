# %%
import matplotlib.pyplot as plt
import numpy as np
from dataless import PYPExtrapolation

# %matplotlib inline

# %%
n = [1, 10, 100]
correctness = [1, 0.99, 0.95]
model = PYPExtrapolation(n, correctness=correctness)
model.predict(np.array([1, 10, 100, 1000, 10000]))
# Out:
# /Volumes/Data/projects/dataless/dataless/extrapolate.py:69: OptimizationWarning: Optimization did not converge: Maximum number of function evaluations has been exceeded.
#   self.train()
# array([1.        , 0.99000117, 0.95000214, 0.88420427, 0.81462242])

# %%
fig, ax = plt.subplots()

n = np.exp(np.log(10) * np.linspace(0, 10, 100))
ax.plot(d.n, d.κ, "o", label="Original data")
ax.plot(n, model.predict(n), label="Extrapolation")
ax.set(xscale="log", xlabel="Population (n)", ylabel="Identification accuracy (κ)", ylim=(0, 1))
ax.legend();

# %%
# Display model summary
print(model.summary())
# Out:
# PYP Extrapolation Model
# =======================
# Trained on: correctness
# Parameters: h=30.4427, gamma=0.8956
# Training points: 3
# Training range: n in [1, 100]
